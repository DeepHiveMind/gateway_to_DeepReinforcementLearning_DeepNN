# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepHiveMind/80-days-study-guide-to-Deep-Learning-Reinforced-Learning-and-Deep-Reinforced-Learning/blob/master/Radiology_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import glob
import cv2
import matplotlib as plt

from google.colab import files
uploaded = files.upload()

labels= pd.read_csv(io.StringIO(r'C:\Users\RAM G\Radiology\sample_labels.csv'))
plt.rcParams['figure.figsize']=[3.0,3.0]
plt.pyplot.subplots_adjust(wspace=0,hspace=0)
multipleImages=glob.glob(r'C:\Users\RAM G\Radiology\sample\images\**.csv')
l=0
for i in multipleImages[:9]:
    im= cv2.imread(i)
    im= cv2.resize(im, (128,128))
    plt.subplot(5,5,i+1)
    plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
    plt.axis('off')
    l+=1
# Out:
#      <input type="file" id="files-f96110d3-f0b8-4d89-9bb8-4b1b62e3a75b" name="files[]" multiple disabled />
#      <output id="result-f96110d3-f0b8-4d89-9bb8-4b1b62e3a75b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import numpy as np
x = '060y'

# %%
x[:-1].astype(int)

# %%
x
# Out:
# '060y'
